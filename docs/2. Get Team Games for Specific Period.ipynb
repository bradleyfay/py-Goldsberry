# %% [markdown]
# Collecting Info on A Specific Teams Games Over a Specific Period
# ===
#
# This vignette shows you how to collect gameids for a specific team during a specific time and aggregate corresponding box score information.
#
# Specifically, it will walk you through collecting information on all Phoenix Suns games that took place during December and January of the 2006-07 season.
#
# If you haven't installed or updated to the latest version of goldsberry installed (see first block below)
#
# ##Installation
#
# If you don't have the package installed, use `pip` install get the latest version
#
#     pip install py-goldsberry
#     pip install --upgrade py-goldsberry
#
# When you have `py-goldsberry` installed, you can load the package and check the version number

# %%
import goldsberry
import pandas as pd
pd.set_option("display.max_columns",50) # Change Pandas Display Options
goldsberry.__version__
# Out:
# '0.6.1'

# %%
gameids = goldsberry.GameIDs()
gameids = pd.DataFrame(gameids)

# %%
filter_season = '2006'
teamids_2006 = gameids['HOME_TEAM_ID'].ix[gameids['SEASON']==filter_season].drop_duplicates().tolist()

def get_team_info(teamids):
    teamids_full = [] # Create empty Data Frame
    for i in teamids:
        team = goldsberry.team.team_info(i)
        teamids_full = teamids_full + team.info()
    return teamids_full

teams_2006 = get_team_info(teamids_2006)
teams_2006 = pd.DataFrame(teams_2006)

# %%
teams_2006
# Out:
#     CONF_RANK  DIV_RANK   L MAX_YEAR MIN_YEAR    PCT SEASON_YEAR  \
# 0           5         2  36     2015     1961  0.561     2014-15
# 1          11         4  49     2015     1988  0.402     2014-15
# 2          14         4  64     2015     1949  0.220     2014-15
# 3           2         1  29     2015     1970  0.646     2014-15
# 4           8         5  37     2015     2002  0.549     2014-15
# 5           2         1  26     2015     1967  0.683     2014-15
# 6          10         3  45     2015     1988  0.451     2014-15
# 7          12         4  52     2015     1976  0.366     2014-15
# 8          14         5  61     2015     1948  0.256     2014-15
# 9          10         3  43     2015     1968  0.476     2014-15
# 10          4         1  33     2015     1995  0.598     2014-15
# 11          9         4  44     2015     1976  0.463     2014-15
# 12          5         2  27     2015     1995  0.671     2014-15
# 13         15         5  66     2015     1989  0.195     2014-15
# 14          3         2  32     2015     1966  0.610     2014-15
# 15          4         1  31     2015     1970  0.622     2014-15
# 16          7         4  32     2015     1980  0.610     2014-15
# 17          1         1  15     2015     1946  0.817     2014-15
# 18          7         2  42     2015     1946  0.488     2014-15
# 19         15         5  65     2015     1946  0.207     2014-15
# 20          1         1  22     2015     1949  0.732     2014-15
# 21          6         3  27     2015     1976  0.671     2014-15
# 22          6         3  41     2015     1968  0.500     2014-15
# 23         12         5  50     2015     1948  0.390     2014-15
# 24         13         5  57     2015     1989  0.305     2014-15
# 25         11         3  44     2015     1974  0.463     2014-15
# 26          3         2  26     2015     1970  0.683     2014-15
# 27          8         3  44     2015     1976  0.463     2014-15
# 28         13         4  53     2015     1948  0.354     2014-15
# 29          9         2  37     2015     1967  0.549     2014-15
#
#    TEAM_ABBREVIATION      TEAM_CITY     TEAM_CODE TEAM_CONFERENCE  \
# 0                WAS     Washington       wizards            East
# 1                CHA      Charlotte       hornets            East
# 2                PHI   Philadelphia        sixers            East
# 3                CLE      Cleveland     cavaliers            East
# 4                NOP    New Orleans      pelicans            West
# 5                HOU        Houston       rockets            West
# 6                MIA          Miami          heat            East
# 7                DEN         Denver       nuggets            West
# 8                LAL    Los Angeles        lakers            West
# 9                PHX        Phoenix          suns            West
# 10               TOR        Toronto       raptors            East
# 11               IND        Indiana        pacers            East
# 12               MEM        Memphis     grizzlies            West
# 13               MIN      Minnesota  timberwolves            West
# 14               CHI        Chicago         bulls            East
# 15               POR       Portland       blazers            West
# 16               DAL         Dallas     mavericks            West
# 17               GSW   Golden State      warriors            West
# 18               BOS         Boston       celtics            East
# 19               NYK       New York        knicks            East
# 20               ATL        Atlanta         hawks            East
# 21               SAS    San Antonio         spurs            West
# 22               MIL      Milwaukee         bucks            East
# 23               DET        Detroit       pistons            East
# 24               ORL        Orlando         magic            East
# 25               UTA           Utah          jazz            West
# 26               LAC    Los Angeles      clippers            West
# 27               BKN       Brooklyn          nets            East
# 28               SAC     Sacramento         kings            West
# 29               OKC  Oklahoma City       thunder            West
#
#    TEAM_DIVISION     TEAM_ID      TEAM_NAME   W
# 0      Southeast  1610612764        Wizards  46
# 1      Southeast  1610612766        Hornets  33
# 2       Atlantic  1610612755          76ers  18
# 3        Central  1610612739      Cavaliers  53
# 4      Southwest  1610612740       Pelicans  45
# 5      Southwest  1610612745        Rockets  56
# 6      Southeast  1610612748           Heat  37
# 7      Northwest  1610612743        Nuggets  30
# 8        Pacific  1610612747         Lakers  21
# 9        Pacific  1610612756           Suns  39
# 10      Atlantic  1610612761        Raptors  49
# 11       Central  1610612754         Pacers  38
# 12     Southwest  1610612763      Grizzlies  55
# 13     Northwest  1610612750   Timberwolves  16
# 14       Central  1610612741          Bulls  50
# 15     Northwest  1610612757  Trail Blazers  51
# 16     Southwest  1610612742      Mavericks  50
# 17       Pacific  1610612744       Warriors  67
# 18      Atlantic  1610612738        Celtics  40
# 19      Atlantic  1610612752         Knicks  17
# 20     Southeast  1610612737          Hawks  60
# 21     Southwest  1610612759          Spurs  55
# 22       Central  1610612749          Bucks  41
# 23       Central  1610612765        Pistons  32
# 24     Southeast  1610612753          Magic  25
# 25     Northwest  1610612762           Jazz  38
# 26       Pacific  1610612746       Clippers  56
# 27      Atlantic  1610612751           Nets  38
# 28       Pacific  1610612758          Kings  29
# 29     Northwest  1610612760        Thunder  45

# %%
teams_2006.ix[teams_2006['TEAM_NAME'].str.contains('Suns')]
# Out:
#    CONF_RANK  DIV_RANK   L MAX_YEAR MIN_YEAR    PCT SEASON_YEAR  \
# 9         10         3  43     2015     1968  0.476     2014-15
#
#   TEAM_ABBREVIATION TEAM_CITY TEAM_CODE TEAM_CONFERENCE TEAM_DIVISION  \
# 9               PHX   Phoenix      suns            West       Pacific
#
#       TEAM_ID TEAM_NAME   W
# 9  1610612756      Suns  39

# %%
suns_id = 1610612756
suns_logs = goldsberry.team.game_logs(suns_id, season='2006')

# %%
suns_logs = pd.DataFrame(suns_logs.TeamGameLog())

# %%
suns_logs.head()
# Out:
#    AST  BLK  DREB  FG3A  FG3M  FG3_PCT  FGA  FGM  FG_PCT  FTA  FTM  FT_PCT  \
# 0   25    6    27    32    10    0.313   86   37   0.430   18   15   0.833
# 1   31    4    24    18     8    0.444   82   47   0.573   18   15   0.833
# 2   31    7    36    23    10    0.435   82   43   0.524   31   30   0.968
# 3   18    5    37    25     7    0.280   89   34   0.382   20   18   0.900
# 4   29    3    27    30    13    0.433   87   43   0.494   11   10   0.909
#
#       GAME_DATE     Game_ID      MATCHUP  MIN  OREB  PF  PTS  REB  STL  TOV  \
# 0  APR 17, 2007  0020601215  PHX vs. LAC  240    10  20   99   37    8   10
# 1  APR 16, 2007  0020601207    PHX @ HOU  240     7  20  117   31    9   13
# 2  APR 14, 2007  0020601192    PHX @ UTA  240     6  23  126   42   11   12
# 3  APR 13, 2007  0020601185  PHX vs. LAL  240    12  11   93   49    4    8
# 4  APR 11, 2007  0020601171  PHX vs. SEA  240    11  13  109   38    9   10
#
#       Team_ID WL
# 0  1610612756  L
# 1  1610612756  L
# 2  1610612756  W
# 3  1610612756  W
# 4  1610612756  W

# %% [markdown]
# Filtering only December and January Games

# %%
suns_logs.ix[suns_logs['GAME_DATE'].str.contains('JAN|DEC')]
# Out:
#     AST  BLK  DREB  FG3A  FG3M  FG3_PCT  FGA  FGM  FG_PCT  FTA  FTM  FT_PCT  \
# 37   25    4    19    36    15    0.417   74   37   0.500   25   23   0.920
# 38   29    4    25    28    13    0.464   77   44   0.571   21   14   0.667
# 39   26    4    33    28    11    0.393   87   37   0.425   20   13   0.650
# 40   23    2    30    21     9    0.429   82   38   0.463   38   27   0.711
# 41   35    4    33    33    13    0.394   79   48   0.608   21   18   0.857
# 42   26    6    37    22     8    0.364   95   54   0.568   19   15   0.789
# 43   28    8    22    16     8    0.500   72   38   0.528   23   22   0.957
# 44   24    7    39    34    17    0.500   79   37   0.468   12    9   0.750
# 45   36    2    28    34    14    0.412   90   50   0.556   28   23   0.821
# 46   26    2    34    25     9    0.360   81   43   0.531   16   12   0.750
# 47   36    7    37    19     6    0.316   89   43   0.483   21   17   0.810
# 48   27    4    38    16     8    0.500   80   46   0.575   19   13   0.684
# 49   34    5    35    32    12    0.375  104   54   0.519   13    8   0.615
# 50   20    1    27    20    11    0.550   76   36   0.474   29   25   0.862
# 51   29   10    35    25    10    0.400   80   37   0.463   18   16   0.889
# 52   24    3    27    23     7    0.304   87   36   0.414   25   18   0.720
# 53   30    3    30    22     9    0.409   80   40   0.500   23   19   0.826
# 54   25    9    27    28    12    0.429   87   43   0.494   11   10   0.909
# 55   24    2    32    14     9    0.643   72   37   0.514   21   16   0.762
# 56   29    4    32    18     9    0.500   82   44   0.537   13   13   1.000
# 57   34    7    34    43    13    0.302  105   52   0.495   28   22   0.786
# 58   26    7    38    15     6    0.400   82   42   0.512   30   25   0.833
# 59   24    4    29    26    11    0.423   81   42   0.519   14   10   0.714
# 60   22    7    42    31     8    0.258   95   41   0.432   18   15   0.833
# 61   22    5    38    26    10    0.385   71   34   0.479   25   21   0.840
# 62   25    7    29    16     4    0.250   74   38   0.514   27   23   0.852
# 63   30    1    36    18     5    0.278   87   46   0.529   20   17   0.850
# 64   32    6    36    20     9    0.450   71   43   0.606   24   21   0.875
# 65   43    5    28    31    17    0.548  117   61   0.521   27   22   0.815
# 66   32    7    35    31    14    0.452   95   47   0.495   22   19   0.864
# 67   26   10    29    26    11    0.423   81   41   0.506   33   29   0.879
#
#        GAME_DATE     Game_ID      MATCHUP  MIN  OREB  PF  PTS  REB  STL  TOV  \
# 37  JAN 29, 2007  0020600664    PHX @ MIN  240     7  17  112   26    4   13
# 38  JAN 28, 2007  0020600655    PHX @ CLE  240     5  13  115   30    5    8
# 39  JAN 26, 2007  0020600641    PHX @ MIL  240    13  22   98   46    5   15
# 40  JAN 24, 2007  0020600626    PHX @ NYK  240     9  22  112   39    9   16
# 41  JAN 23, 2007  0020600616    PHX @ WAS  240     6  19  127   39    5   15
# 42  JAN 21, 2007  0020600604  PHX vs. MIN  240    12  21  131   49    6    8
# 43  JAN 19, 2007  0020600589  PHX vs. POR  240     7  11  106   29    5    9
# 44  JAN 17, 2007  0020600575    PHX @ HOU  240     8  13  100   47    3   18
# 45  JAN 15, 2007  0020600563    PHX @ MEM  240    10  17  137   38    9   13
# 46  JAN 13, 2007  0020600549  PHX vs. ORL  240     9  20  107   43    5   16
# 47  JAN 11, 2007  0020600529  PHX vs. CLE  240    13  19  109   50   11   13
# 48  JAN 09, 2007  0020600514  PHX vs. SEA  240     4  12  113   42    4   14
# 49  JAN 07, 2007  0020600502  PHX vs. GSW  240    11  24  128   46   11   15
# 50  JAN 05, 2007  0020600488  PHX vs. MIA  240     8  17  108   35    8    6
# 51  JAN 03, 2007  0020600467    PHX @ TOR  240     7  18  100   42    9   18
# 52  JAN 02, 2007  0020600463    PHX @ CHI  240    11  19   97   38    9   10
# 53  DEC 31, 2006  0020600453    PHX @ DET  240     4  15  108   34    6    9
# 54  DEC 29, 2006  0020600438  PHX vs. NYK  240    11  17  108   38    4   10
# 55  DEC 28, 2006  0020600426    PHX @ DAL  240     5  27   99   37    3   21
# 56  DEC 26, 2006  0020600412  PHX vs. POR  240     7  20  110   39    9   17
# 57  DEC 22, 2006  0020600391  PHX vs. WAS  265    12  22  139   46    2   12
# 58  DEC 19, 2006  0020600363  PHX vs. TOR  240     5  22  115   43    4   10
# 59  DEC 16, 2006  0020600350    PHX @ SAC  240     5  23  105   34    8   18
# 60  DEC 15, 2006  0020600338  PHX vs. GSW  240    10  15  105   52    5   16
# 61  DEC 13, 2006  0020600316    PHX @ MIA  240     8  21   99   46    6   15
# 62  DEC 11, 2006  0020600301    PHX @ ORL  240     7  18  103   36    8   16
# 63  DEC 10, 2006  0020600296    PHX @ CHA  240    11  18  114   47    9   10
# 64  DEC 08, 2006  0020600277    PHX @ BOS  240     4  18  116   40    6   19
# 65  DEC 07, 2006  0020600271    PHX @ NJN  290    11  28  161   39   10   12
# 66  DEC 05, 2006  0020600258  PHX vs. SAC  240    15  19  127   50    6   13
# 67  DEC 01, 2006  0020600231  PHX vs. MIL  240    11  22  122   40    7   14
#
#        Team_ID WL
# 37  1610612756  L
# 38  1610612756  W
# 39  1610612756  W
# 40  1610612756  W
# 41  1610612756  W
# 42  1610612756  W
# 43  1610612756  W
# 44  1610612756  W
# 45  1610612756  W
# 46  1610612756  W
# 47  1610612756  W
# 48  1610612756  W
# 49  1610612756  W
# 50  1610612756  W
# 51  1610612756  W
# 52  1610612756  W
# 53  1610612756  W
# 54  1610612756  W
# 55  1610612756  L
# 56  1610612756  W
# 57  1610612756  L
# 58  1610612756  W
# 59  1610612756  W
# 60  1610612756  W
# 61  1610612756  W
# 62  1610612756  W
# 63  1610612756  W
# 64  1610612756  W
# 65  1610612756  W
# 66  1610612756  W
# 67  1610612756  W

# %%
# GameIDs for filtered Games
suns_2006_dec_jan = suns_logs['Game_ID'].ix[suns_logs['GAME_DATE'].str.contains('JAN|DEC')].tolist()

# %%
def get_boxscore_player_info(gameids):
    bs_info = []
    for i in gameids:
        info = goldsberry.game.boxscore_traditional(i, rangetype=0) # Adjust rangetype API paramter to return DNP
        bs_info = bs_info + info.player_stats()
    return bs_info

# %%
player_box_info = get_boxscore_player_info(suns_2006_dec_jan)

# %%
player_box_info = pd.DataFrame(player_box_info)

# %% [markdown]
# From here, we can filter comments to see why anyone may not have played.

# %%
player_box_info['COMMENT'].value_counts()
# Out:
#                                             603
# DNP - Coach's Decision                      129
# NWT - NBA Suspension                          4
# NWT - NBA suspension                          1
# DND - Salmonella Infection                    1
# DND - Fractured Metacarpal, Right Hand        1
# DND - Sprained Right Wrist                    1
# DND - Left Ankle Sprain                       1
# DND - Strained Tendon Sheath, Right Hand      1
# DND - Sore Left Foot                          1
# NWT - Team Suspension                         1
# dtype: int64

# %% [markdown]
# To get a list of games where Steve Nash did or did not play, we can use some filtering in Pandas

# %%
player_box_info.head()
# Out:
#    AST  BLK COMMENT  DREB  FG3A  FG3M  FG3_PCT  FGA  FGM  FG_PCT  FTA  FTM  \
# 0    3    0             0     4     2    0.500    7    4   0.571    2    2
# 1    0    2             9     3     3    1.000   10    8   0.800    5    5
# 2    0    1             0     0     0    0.000    5    2   0.400    7    6
# 3    2    0             2    11     5    0.455   17    9   0.529    4    3
# 4   18    0             4     8     3    0.375   14    7   0.500    3    3
#
#    FT_PCT     GAME_ID    MIN  OREB  PF  PLAYER_ID        PLAYER_NAME  \
# 0   1.000  0020600664  32:58     0   1       2564         Boris Diaw
# 1   1.000  0020600664  39:35     1   5       1890       Shawn Marion
# 2   0.857  0020600664  39:42     4   2       2405  Amar'e Stoudemire
# 3   0.750  0020600664  35:43     0   4       1952          Raja Bell
# 4   1.000  0020600664  35:39     1   1        959         Steve Nash
#
#    PLUS_MINUS  PTS  REB START_POSITION  STL TEAM_ABBREVIATION TEAM_CITY  \
# 0         -17   12    0              F    1               PHX   Phoenix
# 1          -2   24   10              F    2               PHX   Phoenix
# 2           2   10    4              C    0               PHX   Phoenix
# 3          -4   26    2              G    0               PHX   Phoenix
# 4           5   20    5              G    0               PHX   Phoenix
#
#       TEAM_ID  TO
# 0  1610612756   0
# 1  1610612756   1
# 2  1610612756   3
# 3  1610612756   2
# 4  1610612756   5

# %%
player_box_info.ix[player_box_info['PLAYER_NAME'] == "Steve Nash"]
# Out:
#      AST  BLK COMMENT  DREB  FG3A  FG3M  FG3_PCT  FGA  FGM  FG_PCT  FTA  FTM  \
# 4     18    0             4     8     3    0.375   14    7   0.500    3    3
# 28    15    0             2     6     3    0.500   17   10   0.588    0    0
# 52    16    0             3     3     2    0.667   14    7   0.500    2    2
# 76    14    0             5     6     3    0.500   15    7   0.467    8    5
# 100   14    0             3     4     3    0.750   13   11   0.846    2    2
# 136   11    0             3     4     2    0.500   12    6   0.500    2    2
# 160   15    0             1     2     0    0.000    8    4   0.500    5    5
# 171   14    0             2     5     3    0.600   10    8   0.800    2    2
# 196   15    1             0     6     2    0.333   10    5   0.500    0    0
# 232    8    0             4     7     2    0.286   15    8   0.533    7    5
# 256   21    0             4     1     0    0.000    7    2   0.286    0    0
# 280   11    0             3     7     5    0.714   15   11   0.733    0    0
# 304   10    0             2     7     2    0.286   14    6   0.429    0    0
# 328    4    0             5     6     4    0.667   14    8   0.571    2    2
# 340    9    0             3     7     2    0.286   13    5   0.385    3    3
# 363   13    0             2     2     1    0.500    9    4   0.444    3    2
# 388   12    0             4    11     6    0.545   19   12   0.632    5    5
# 424    9    0             1     7     5    0.714   12    7   0.583    1    1
# 436   13    0             4     4     3    0.750   14   10   0.714    2    1
# 472    5    0             2     1     1    1.000   10    4   0.400    0    0
# 496   12    0             3    15     7    0.467   25   14   0.560    9    7
# 520   15    0             5     4     3    0.750    9    3   0.333    2    1
# 532   12    0             4     5     2    0.400   15    7   0.467    0    0
# 568    5    0             3     8     4    0.500   13    6   0.462    0    0
# 580   11    0             3     4     2    0.500    9    5   0.556    6    6
# 604   15    0             4     3     1    0.333   10    6   0.600    5    5
# 628   10    0             0     3     0    0.000   13    5   0.385    1    1
# 652   14    0             5     3     1    0.333    8    6   0.750    3    3
# 676   13    0             5     7     6    0.857   25   16   0.640    5    4
# 712   20    0             3     4     3    0.750    8    4   0.500    0    0
# 736   11    0             2     4     4    1.000   11    8   0.727    8    7
#
#      FT_PCT     GAME_ID    MIN  OREB  PF  PLAYER_ID PLAYER_NAME  PLUS_MINUS  \
# 4     1.000  0020600664  35:39     1   1        959  Steve Nash           5
# 28    0.000  0020600655  35:37     1   2        959  Steve Nash          13
# 52    1.000  0020600641  35:35     3   2        959  Steve Nash          12
# 76    0.625  0020600626  35:25     0   2        959  Steve Nash          13
# 100   1.000  0020600616  35:36     0   1        959  Steve Nash          17
# 136   1.000  0020600604  27:55     0   0        959  Steve Nash          37
# 160   1.000  0020600589  35:40     0   1        959  Steve Nash          10
# 171   1.000  0020600575  36:51     2   2        959  Steve Nash          11
# 196   0.000  0020600563  34:46     1   0        959  Steve Nash          11
# 232   0.714  0020600549  36:48     1   1        959  Steve Nash          14
# 256   0.000  0020600529  30:15     0   2        959  Steve Nash          21
# 280   0.000  0020600514  36:09     0   0        959  Steve Nash           0
# 304   0.000  0020600502  30:05     0   3        959  Steve Nash          13
# 328   1.000  0020600488  31:53     0   1        959  Steve Nash          14
# 340   1.000  0020600467  36:18     1   2        959  Steve Nash           5
# 363   0.667  0020600463  37:11     0   2        959  Steve Nash           8
# 388   1.000  0020600453  39:34     0   1        959  Steve Nash          13
# 424   1.000  0020600438  35:22     0   2        959  Steve Nash          16
# 436   0.500  0020600426  36:36     0   1        959  Steve Nash           0
# 472   0.000  0020600412  27:51     0   0        959  Steve Nash          18
# 496   0.778  0020600391  42:13     0   2        959  Steve Nash          -9
# 520   0.500  0020600363  28:21     0   2        959  Steve Nash          27
# 532   0.000  0020600350  37:45     1   2        959  Steve Nash           6
# 568   0.000  0020600338  37:35     2   0        959  Steve Nash          -9
# 580   1.000  0020600316  34:54     0   1        959  Steve Nash          -2
# 604   1.000  0020600301  37:17     1   2        959  Steve Nash          18
# 628   1.000  0020600296  27:01     0   1        959  Steve Nash          10
# 652   1.000  0020600277  36:13     0   0        959  Steve Nash           5
# 676   0.800  0020600271  47:57     1   3        959  Steve Nash           6
# 712   0.000  0020600258  32:34     1   1        959  Steve Nash          18
# 736   0.875  0020600231  38:07     0   2        959  Steve Nash          11
#
#      PTS  REB START_POSITION  STL TEAM_ABBREVIATION TEAM_CITY     TEAM_ID  TO
# 4     20    5              G    0               PHX   Phoenix  1610612756   5
# 28    23    3              G    0               PHX   Phoenix  1610612756   0
# 52    18    6              G    0               PHX   Phoenix  1610612756   8
# 76    22    5              G    1               PHX   Phoenix  1610612756   6
# 100   27    3              G    0               PHX   Phoenix  1610612756   5
# 136   16    3              G    1               PHX   Phoenix  1610612756   0
# 160   13    1              G    1               PHX   Phoenix  1610612756   0
# 171   21    4              G    1               PHX   Phoenix  1610612756   6
# 196   12    1              G    0               PHX   Phoenix  1610612756   3
# 232   23    5              G    0               PHX   Phoenix  1610612756   3
# 256    4    4              G    1               PHX   Phoenix  1610612756   1
# 280   27    3              G    1               PHX   Phoenix  1610612756   5
# 304   14    2              G    1               PHX   Phoenix  1610612756   6
# 328   22    5              G    0               PHX   Phoenix  1610612756   0
# 340   15    4              G    1               PHX   Phoenix  1610612756   7
# 363   11    2              G    0               PHX   Phoenix  1610612756   2
# 388   35    4              G    1               PHX   Phoenix  1610612756   3
# 424   20    1              G    0               PHX   Phoenix  1610612756   6
# 436   24    4              G    0               PHX   Phoenix  1610612756   3
# 472    9    2              G    1               PHX   Phoenix  1610612756   4
# 496   42    3              G    0               PHX   Phoenix  1610612756   5
# 520   10    5              G    2               PHX   Phoenix  1610612756   3
# 532   16    5              G    1               PHX   Phoenix  1610612756   5
# 568   16    5              G    1               PHX   Phoenix  1610612756   5
# 580   18    3              G    1               PHX   Phoenix  1610612756   4
# 604   18    5              G    1               PHX   Phoenix  1610612756   4
# 628   11    0              G    2               PHX   Phoenix  1610612756   1
# 652   16    5              G    1               PHX   Phoenix  1610612756   6
# 676   42    6              G    1               PHX   Phoenix  1610612756   3
# 712   11    4              G    2               PHX   Phoenix  1610612756   3
# 736   27    2              G    1               PHX   Phoenix  1610612756   4

# %% [markdown]
# I looks like Nash played every game during this stretch
